# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath("/Users/qhddn/RL class/Mid-term project"))
from mid_project import n_step_SARSA

# %%
env = gym.make('FrozenLake-v1',
               desc=["SFFFFH", "FHFHFF", "FFFHFF", "HFFFGF"],
               is_slippery=False)

# call your algorithm to solve this domain
nsarsa = n_step_SARSA(env, n_episode=2000, alpha=0.4, gamma=1.0, epsilon=0.01, n=16, tag="FrozenLake")
Q, policy, rewards, num_step = nsarsa.play()

nsarsa.plot_rewards(rewards)

nsarsa.plot_steps_episodes(num_step)

nsarsa.print_optimal_policy(policy)
# Out:
# Optimal Policy of FrozenLake
# [['←' '←' '←' '↑' '↑' '↑']
#  ['←' '↑' '↑' '↑' '↑' '↑']
#  ['←' '←' '↑' '↑' '↑' '↑']
#  ['↑' '↑' '↑' '↑' '↑' '↑']]

# %% [markdown]
# - Plot sum of rewards over number of episodes
# - Plot number of steps per episode over the number of episodes
# - Show the animation of the agent workiround or plot the policy

# %%
env = gym.make('FrozenLake-v1',
               desc=["SFFFFH", "FHFHFF", "FFFHFF", "HFFFGF"],
               is_slippery=True)
#call your algorithm to solve this domain

nsarsa = n_step_SARSA(env, n_episode=2000, alpha=0.4, gamma=1.0, epsilon=0.01, n=16, tag="FrozenLake")
Q, policy, rewards, num_step = nsarsa.play()

nsarsa.plot_rewards(rewards)

nsarsa.plot_steps_episodes(num_step)

nsarsa.print_optimal_policy(policy)
# Out:
# Optimal Policy of FrozenLake
# [['←' '←' '↑' '↑' '↑' '↑']
#  ['←' '↑' '↑' '↑' '↑' '↑']
#  ['←' '←' '↑' '↑' '↑' '↑']
#  ['↑' '←' '↑' '↑' '↑' '↑']]

# %% [markdown]
# - Plot sum of rewards over number of episodes
# - Plot number of steps per episode over the number of episodes
# - Show the animation of the agent working or plot the policy
